# %% [markdown]
# # Python Programming Basic 1-1

# %% [markdown]
# # 변수 Variable, 자료형 Data Types, 연산 Operation

# %% [markdown]
# ## 1.변수
#
# - 프로그래밍에서 데이터를 담는 그릇
# - 명명 규칙
#     - 숫자, 대소영문자 사용가능 : a-zA-Z0-9
#     - 변수명은 영소문자로 시작 : abc123 (o), Abc123 (x), 123abc (x)
#     - 단어간 연결시 _로 연결 : 예) python_programming

# %% [markdown]
# - 변수 사용 및 결과 출력
# ```python
# # 변수 초기화
# 변수명 = 데이터(자료)
# ```
# ```python
# # 결과 출력
# print(데이터 or 변수명)
# ```

# %%
height = 183

# %%
name = 'playdata'

# %%
print(height)
# Out:
# 183

# %% [markdown]
# ## 2.자료형 Data Types
# - 프로그래밍 언어에서 데이터를 식별하는 분류 기준

# %% [markdown]
# #### 1) 숫자형 Numeric Types
#
# - 정수형 int(integer)

# %%
a=3

# %%
print(a)
# Out:
# 3

# %% [markdown]
# - 실수형 float

# %%
b=75.5

# %%
print(b)
# Out:
# 75.5

# %%
print(type(a))
print(type(b))
print(type(a+b))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# #### *숫자형 연산 Operation
# - 산술 연산

# %%
print(10 + 3) # 덧셈
print(10 - 3) # 뺄셈
print(10 * 3) # 곱셈
print(10 / 3) # 나눗셈
print(10 // 3) #몫
print(10 % 3) #나머지
print(10 ** 3)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# - 복합 연산

# %%
c = 10
print(c)
# Out:
# 10

# %%
c += 3 # += : c = c + 3
print(c)

c -= 3 # -= : c = c - 3
print(c)

c *= 3 # *= : c = c * 3
print(c)

c /= 3 # /= : c = c / 3
print(c)
# Out:
# 13
# 10
# 30
# 10.0

# %% [markdown]
# #### 2) 불리언 Boolean
#
# - 참 True / 거짓 False

# %%
t = True

# %%
print(t)
# Out:
# True

# %%
print(type(t))
# Out:
# <class 'bool'>

# %% [markdown]
# #### *불리언 연산과 비교연산

# %% [markdown]
# - 비교연산 Comparisons
#     - < : 작다
#     - <= : 작거나 같다
#     - \> : 크다
#     - \>= : 크거나 같다
#     - == : 같다
#     - != : 다르다

# %%
print(1 != 2)
# Out:
# True

# %% [markdown]
# - 논리 연산 Logical Operations
#     - and : 하나라도 거짓인 값이 존재할 때, 결과는 False
#     - or :  둘다 모두 거짓인 값일 때, 결과는 False
#     - not : 기존의 값을 반대로 바꿀 때, 결과는 기존 값 반대 (True -> False, False -> True)

# %%
t = True
f = False

# %%
# and
print (t and t) # True
print (t and f) # False
print (f and f) # False

# or
print(t or t) # True
print(t or f) # True
print(f or f) # False

# not
print(not t) # False
print(not f) # True
# Out:
# True
# False
# False
# True
# True
# False
# False
# True

# %% [markdown]
# #### 3) 문자 시퀀스형 Text Sequence Type
#
# - 문자열 str
#     - 작은따옴표 Single Quotes('') 혹은 큰 따옴표 Double Quotes("") 내 문자, 숫자, 기호 등의 집합
#
#
# - Python 간단한 소개글
# ```
# Python is powerful... and fast;
# plays well with others;
# runs everywhere;
# is friendly & easy to learn;
# is Open.
# ```

# %%
single_quotes = 'String'
print(single_quotes, type(single_quotes))
# Out:
# String <class 'str'>

# %%
double_quotes = 'String'
print(double_quotes, type(double_quotes))
# Out:
# String <class 'str'>

# %%
triple_quoted = '''Python is powerful... and fast;
plays well with others;
runs everywhere;
is friendly & easy to learn;
is Open.'''
print(triple_quoted)
# Out:
# Python is powerful... and fast;
# plays well with others;
# runs everywhere;
# is friendly & easy to learn;
# is Open.

# %%
# 반드시 짝(시작과 끝)을 맞추어야 합니다
'String"
# Out:
#   File "<ipython-input-31-2bb85c49af19>", line 2
#     'String"
#             ^
# SyntaxError: EOL while scanning string literal

# %%
sentence1 = "I'd like to programming"
print(sentence1)
# Out:
# I'd like to programming

# %%
sentence2 = 'using python!'
print(sentence2)
# Out:
# using python!

# %% [markdown]
# #### *문자열 연산

# %%
# + 덧셈연산 : 연결된 문자열 반환
sentence1 + sentence2
# Out:
# "I'd like to programmingusing python!"

# %%
# * 곱셈연산 : 횟수만큼 반복된 문자열 반환
sentence1 * 3
# Out:
# "I'd like to programmingI'd like to programmingI'd like to programming"

# %% [markdown]
# #### *문자열 활용

# %% [markdown]
# - 인덱싱 indexing & 슬라이싱 slicing

# %%
institute = 'playdata'
ins = 'playdata'

# %%
# len() : 문자열의 길이를 반환
print(len(ins))
print(ins[7])
# Out:
# 8
# a

# %%
# [idx1:idx2] : idx1 부터 idx2-1까지 인덱스 요소들을 문자열로 반환
print(ins[1:7])
# Out:
# laydat

# %% [markdown]
# #### *문자열 출력
# - % 형식화 Formatting
#     - %s : 문자열
#     - %d : 정수
#     - %f : 실수

# %%
lecture = "python programming"
print("지금은 %s 을 학습하고 있습니다."% lecture)
# Out:
# 지금은 python programming 을 학습하고 있습니다.

# %%
year = 2021
print("올해는 %i 년 입니다"% year)
# Out:
# 올해는 2021 년 입니다

# %%
exchange_rate = 1186.84
print("금일 미국 달러 환율은 1달러 = %.2f 원입니다"% exchange_rate)
# Out:
# 금일 미국 달러 환율은 1달러 = 1186.84 원입니다

# %% [markdown]
# - format() : { }괄호 내부에 데이터 출력

# %%
# type 무관하게 데이터 출력 가능
print("format을 활용하여 {0}, {0} 데이터 출력합니다.".format(lecture,year))
# Out:
# format을 활용하여 python programming, python programming 데이터 출력합니다.

# %% [markdown]
# - f-문자열 f-string : f'string'형식의 문자열로서 { } 괄호 내부에 변수 사용 가능

# %%
skill = "python"
print(f"학습하고 있는 프로그래밍 언어는 {skill} 입니다.")
# Out:
# 학습하고 있는 프로그래밍 언어는 python 입니다.

# %% [markdown]
# - replace() : 지정 문자열을 새로운 문자열로 치환하는 함수

# %%
programming_lang = "I can use python"
programming_lang.replace("python","flask")
# Out:
# 'I can use flask'

# %% [markdown]
# - upper() & lower() : 대문자, 소문자로 변환하는 함수

# %%
programming_lang.upper()
# Out:
# 'I CAN USE PYTHON'

# %%
programming_lang.lower()
# Out:
# 'i can use python'

# %% [markdown]
# - count() : 입력받은 문자열 반복 횟수를 반환하는 함수

# %%
tutorial_contents = """The Python Tutorial
Python is an easy to learn, powerful programming language. It has efficient high-level data structures and a simple but effective approach to object-oriented programming. Python’s elegant syntax and dynamic typing, together with its interpreted nature, make it an ideal language for scripting and rapid application development in many areas on most platforms.

The Python interpreter and the extensive standard library are freely available in source or binary form for all major platforms from the Python Web site, https://www.python.org/, and may be freely distributed. The same site also contains distributions of and pointers to many free third party Python modules, programs and tools, and additional documentation.

The Python interpreter is easily extended with new functions and data types implemented in C or C++ (or other languages callable from C). Python is also suitable as an extension language for customizable applications.

This tutorial introduces the reader informally to the basic concepts and features of the Python language and system. It helps to have a Python interpreter handy for hands-on experience, but all examples are self-contained, so the tutorial can be read off-line as well.

For a description of standard objects and modules, see The Python Standard Library. The Python Language Reference gives a more formal definition of the language. To write extensions in C or C++, read Extending and Embedding the Python Interpreter and Python/C API Reference Manual. There are also several books covering Python in depth.

This tutorial does not attempt to be comprehensive and cover every single feature, or even every commonly used feature. Instead, it introduces many of Python’s most noteworthy features, and will give you a good idea of the language’s flavor and style. After reading it, you will be able to read and write Python modules and programs, and you will be ready to learn more about the various Python library modules described in The Python Standard Library."""

# %%
# python 반복 횟수
tutorial_contents.count('Python')
# Out:
# 19

# %% [markdown]
# - split() : 지정 문자 혹은 기호를 기준으로 문자열을 나누는 함수

# %%
title = 'Hello Python Programming Basic'

# %%
title.split()
# Out:
# ['Hello', 'Python', 'Programming', 'Basic']
