# %% [markdown]
# # Python Programming Basic 1-3

# %% [markdown]
# # 제어 흐름 Control Flow

# %% [markdown]
# ### 1.조건문 Condition
# - 특정 조건에 부합할 때 지정 명령어를 수행하는 구문

# %% [markdown]
#   ### 1) if 문

# %% [markdown]
# ```python
# if 조건1:
# 	조건1이 참일 때, 실행되는 명령어
# elif 조건2:
# 	조건2가 참일 때, 실행되는 명령어
# else:
# 	지금까지 어떤 조건도 참이 아니면 실행되는 명령어
# ```

# %% [markdown]
# \* **주의사항**
# 1. 조건과 콜론(:)은 붙여 사용
# 2. 조건 구문마다 실행되는 명령어 구문은 들여쓰기로 구분

# %%
# 기본 if
# Out:
# 조건문 실행

# %%
# Out:
# 조건문 실행1

# %%
# Pass/Fail 판별 프로그램(70점 이상 pass, 그렇지 않으면 fail)
# input(statement) : 새로운 입력창을 통해 값을 입력할 수 있는 함수
# Out:
# score를 입력해주세요. 55
# 결과 : 해당 교과목 Fail

# %%
# 사분기 판별 프로그램(1분기 : 1~3월, 2분기 : 4~6월, 3분기 : 7~9월, 4분기 : 10~12월)

# %% [markdown]
# ## 2.반복문 Iteration
# - 프로그래밍내에서 반복되는 작업을 처리할 때 사용되는 구문

# %% [markdown]
# - 반복문의 종류
#   ### 1) for 문
# ```python
# for 변수 in 시퀀스 자료형:
#             수행코드
# ```

# %%
# 문자열 출력

# %%
# 리스트 요소 출력

# %%
# 1부터 10까지 출력하기

# %%
# range(i) : 지정 횟수만큼 반복 가능한 객체 생성

# %%
# Out:
# 반복문 실행 :  1
# 반복문 실행 :  2
# 반복문 실행 :  3
# 반복문 실행 :  4
# 반복문 실행 :  5
# 반복문 실행 :  6
# 반복문 실행 :  7
# 반복문 실행 :  8
# 반복문 실행 :  9
# 반복문 실행 :  10

# %% [markdown]
# ### 2) while문
# ```python
#     while 조건:
#         수행코드
# ```

# %%
# 기본 while문

# %%
# 횟수 제한 while문
# 'x번째 반복' 글자를 10회만 출력하고 싶다면?
# Out:
# 1 번째 반복
# 2 번째 반복
# 3 번째 반복
# 4 번째 반복
# 5 번째 반복
# 6 번째 반복
# 7 번째 반복
# 8 번째 반복
# 9 번째 반복
# 10 번째 반복

# %%
# 카운트 다운 프로그램 만들기 : 10초, 9초, ... 1초 어떻게 만들 수 있을까?

# %%
count_num = 10
# Out:
# 카운트 다운 :  10 초
# 카운트 다운 :  9 초
# 카운트 다운 :  8 초
# 카운트 다운 :  7 초
# 카운트 다운 :  6 초
# 카운트 다운 :  5 초
# 카운트 다운 :  4 초
# 카운트 다운 :  3 초
# 카운트 다운 :  2 초
# 카운트 다운 :  1 초

# %% [markdown]
# - break, countinue 로 반복문 제어하기
#     1. break : 코드 실행 생략, 제어문 중단
#     2. countinue : 코드 실행 생략, 제어문 유지

# %% [markdown]
# ## 3.중첩 제어문
# - 조건문 내 또 다른 조건문
# - 반복문 내 또 다른 반복문
# - 조건문 내 반복문 혹은 반복문 내 조건문

# %%
# 두 수(num1, num2)의 크기 비교 프로그램
# 1. 두 수의 크기가 같다면? 'num1과 num2의 크기는 같습니다.' 문구 출력
# 2. 두 수의 크기가 다르다면? 
    # 2-1. num1 > num2 라면? 'num1이 num2보다 큽니다.' 문구 출력
    # 2-2. num2 > num1 라면? 'num2이 num1보다 큽니다.' 문구 출력
num1 = 10
num2 = 11

# %%
# 구구단 만들기

# %%
# 1부터 100까지 숫자중에서 홀수만 출력하려면?
