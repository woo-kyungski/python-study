# %% [markdown]
# # Python Programming Basic 1-2

# %% [markdown]
# # 시퀀스 자료형 Sequence Types

# %% [markdown]
# ## 1.리스트 List
#
# - 일반적으로 동일한 자료형 데이터의 집합 객체로 사용
# - 가장 많이 사용되는 시퀀스 객체 중 하나

# %% [markdown]
# #### 1) 리스트 생성
# - 방법 1
#     - 리스트 변수 = [[데이터1], [데이터2], ...]
#
#
# - 방법 2
#     - 리스트 변수 = list([데이터1, 데이터2, ...])

# %%
# 파이썬 데이터 타입 확인 : type(데이터 혹은 변수명)
list1 = 
print(list1, type(list1))
# Out:
# [] <class 'list'>

# %%
list2 = 
print(list2, type(list2))
# Out:
# [] <class 'list'>

# %%
list1 = list()
print(list1, type(list1))
# Out:
# [1, 2, 3, 4, 5] <class 'list'>

# %%
list2 = 
print(list2, type(list2))
# Out:
# [1, 2, 3, 4, 5] <class 'list'>

# %% [markdown]
# #### 2) 리스트 내부 데이터 추출 : 인덱싱, 슬라이싱

# %%
a = 
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 리스트 길이 구하기 : len(리스트 변수)

# %%
# 3만 추출하고 싶다면?
# Out:
# 3

# %%
# 연산도 가능?

# %%
# 3부터 5까지추출

# %%
b = [1, 2, 3, ['a', 'b', 'c', ['one', 'two', 'three']]]

# %%
# 'b' 문자만 출력하기
# Out:
# b

# %%
# 'three' 문자열 출력하기
# Out:
# three

# %% [markdown]
# #### 3) 리스트 수정 및 삭제

# %%
programming_lang = ['python', 'java', 'javascript']
print(programming_lang)
# Out:
# ['python', 'java', 'javascript']

# %% [markdown]
# - 요소 수정
#     - 해당 인덱스에 존재하는 요소 값을 직접 변경

# %%
# python -> pyhton3으로 변경하려면?
# Out:
# ['pyhton3', 'java', 'javascript']

# %% [markdown]
# - 요소 삭제
#     - del 리스트내 요소 : 리스트 내부 지정 요소를 삭제

# %%
# 삭제 전
print(programming_lang)
# Out:
# ['pyhton3', 'java', 'javascript']

# %%
# 삭제 후
# 삭제 test1

# %%
programming_lang = ['python', 'java', 'javascript']
print(programming_lang)

# %%
# 삭제 test2 : 슬라이싱으로 요소 삭제
print('삭제 전 : ', programming_lang)

print('삭제 후 : ', programming_lang)
# Out:
# 삭제 전 :  ['pyhton3', 'java', 'javascript']
# 삭제 후 :  ['pyhton3']

# %% [markdown]
# #### 4) 리스트 활용

# %% [markdown]
# - 요소 추가
#     - append(data) : 리스트 맨 뒤에, 지정한 요소를 추가
#     - insert(idx, data) : 리스트 idx 위치에 지정한 요소를 추가

# %%
fruits = ['apple', 'banana', 'grape']
print(fruits)
# Out:
# ['apple', 'banana', 'grape']

# %%
# append
# Out:
# ['apple', 'banana', 'grape', 'kiwi']

# %%
# insert
# Out:
# ['apple', 'banana', 'orange', 'grape', 'kiwi']

# %% [markdown]
# - 요소 삭제
#     - remove(data) : 리스트 내 지정한 요소와 같은 첫번째 내용을 삭제

# %%
fruits = ['apple', 'banana', 'grape']
print(fruits)
# Out:
# ['apple', 'banana', 'grape']

# %%
# Out:
# ['apple', 'banana', 'grape', 'banana']

# %%
# remove

# %% [markdown]
# - 요소 추출 및 삭제
#     - pop([idx])
#     ```
#         * 인덱스 지정시, 리스트 내 지정 인덱스 요소 반환 후 리스트에서 삭제
#         * 인덱스 미지정시, 리스트 내 맨 뒤 요소 반환 후 리스트에서 삭제
#     ```

# %%
fruits = ['apple', 'banana', 'grape']
print(fruits)
# Out:
# ['apple', 'banana', 'grape']

# %%
# Out:
# 'grape'

# %%
print(fruits)
# Out:
# ['apple', 'banana']

# %%
# Out:
# 'apple'

# %%
print(fruits)
# Out:
# ['banana']
