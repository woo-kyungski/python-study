# %% [markdown]
# # Python Programming Basic 1 실전

# %% [markdown]
# ## 삐빅, 거기 과속차량! 차량번호 xxxx!!! 우측으로 정지하세요!!!
# - 월요일 아침 출근길에 교통 경찰이 과속을 단속하고 있습니다. 아니나 다를까요. 차량 번호판 '2021월 1025' 부착한 차량이 과속했네요. 다급한 목소리로 번호판 뒷자리(4자리 숫자)만을 외치는 교통 경찰, 파이썬으로 번호판 뒷자리(4자리 숫자)만을 출력해주세요.
#     - car_plate = '2021월 1025'

# %%
car_plate = '2021월 1025'

# %% [markdown]
# ### 결과
# 1025

# %% [markdown]
# ## 오늘 뭐먹지 사내 식당 메뉴 읊어줘, 후식은 빼고...
# - 오늘 뭐먹지 사내 식당의 메뉴(평일 석식)는 [밥, 국, 반찬1, 반찬2, 후식] 순서대로 총 5가지로 이루어져 있습니다. 살찐자가 되지 않기 위해 후식은 먹지 않으려고 하는데요. 10월 25일 월요일 석식에서 후식을 제외한 나머지 메뉴를 출력해주세요.
#     - mon_menu = ['참치야채비빔밥', '바지락된장찌개', '훈제오리', '백김치', '블루베리크림타르트']

# %%
mon_menu = ['참치야채비빔밥', '바지락된장찌개', '훈제오리', '백김치', '블루베리크림타르트']

# %% [markdown]
# ### 결과
# 참치야채비빔밥 <br>
# 바지락된장찌개 <br>
# 훈제오리 <br>
# 백김치

# %% [markdown]
# ## 담임 선생님의 채점을 도와주세요, 플리즈
# - 다음은 A반 학생들의 중간고사 시험 성적입니다. 성적 평균을 구해주세요. (소수점 2째자리까지만 출력해주세요.)
#     - scores = [53, 67, 42, 99, 29, 87, 44, 75, 23, 76, 49, 63, 92, 79, 70]

# %%
scores = [53, 67, 42, 99, 29, 87, 44, 75, 23, 76, 49, 63, 92, 79, 70, 35, 27, 100, 47]

# %% [markdown]
# ### 결과
# 60.89

# %% [markdown]
# ## 위 아더 챔피언!
# - 올림픽은 국제올림픽위원회(IOC)가 선정한 도시에서 4년마다 개최되는 국제 경기대회 입니다. 2024년부터 2050년 사이에 개최될 하계올림픽 년도를 출력해주세요. (2024년은 파리에서 열릴 예정입니다.)

# %% [markdown]
# ### 결과
# 2024년 <br>
# 2028년 <br>
# 2032년 <br>
# 2036년 <br>
# 2040년 <br>
# 2044년 <br>
# 2048년

# %% [markdown]
# ## 너는 누구니?
# - 우리나라의 주민등록번호는 뒷자리 첫번째 자리숫자를 가지고 남성(1, 3)과 여성(2, 4)을 구분합니다. 이를 구분하는 프로그램을 만들어주세요.
#     - 예) serial_no = '871025-1234567' -> 남성입니다.

# %%
serial_no = '831025-1234567'

# %% [markdown]
# ### 결과
# 남성입니다.

# %% [markdown]
# ## 알뜰하게 소비합...시다
# - 쇼핑을 위해 위시리스트에 담아놓은 물품 중, b 혹은 p로 시작하는 단어들만 출력해주세요.
#     - wish_list = ['note', 'lotion', 'cup', 'book', 'doll', 'spoon', 'potato', 'onion', 'butter', 'pen']

# %%
wish_list = ['note', 'lotion', 'cup', 'book', 'doll', 'spoon', 'potato', 'onion', 'butter', 'pen']

# %% [markdown]
# ### 결과
# book <br>
# potato <br>
# butter <br>
# pen

# %% [markdown]
# ## 종일 파일 파일정리만 할겐가
# - 파일 목록에서 파일 확장자가 xlsx인 파일들만 출력해주세요
#     - files = ['movie.xls', 'report.doc', 'stock.xlsx', 'print.png', 'database.hwp', 'voca.xlsx']

# %%
files = ['movie.xls', 'report.doc', 'stock.xlsx', 'print.png', 'database.hwp', 'voca.xlsx']

# %% [markdown]
# ### 결과
# stock.xlsx <br>
# voca.xlsx
